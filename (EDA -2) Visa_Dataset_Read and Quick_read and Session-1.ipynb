# %%
#EDA - we rqd some packages
#--------------data frame Analysis -----------
## Pandas == dataframe analysis
#dataframe -- analysis of 

#---------------- Numerical Analysis --------------------
## numpy -- numberical analysis / data analysis

#-------------plotting Analysis ---------------
## matplotlib ( for plotting any diagrams mat-plot-library)
## seaborn === used to plot diagrams
## bokhe === plot diagrams
# plot the diagram -- data visualization (powerBI/ Tableau)

# ML

# sikitlearn ==>sklearn

## 5 packages
# pandas numpy matplotlib seaborn sklearn ---> default packages within python 

# -----------image analytics ------------------
## tensorflow (Deep Learning) ==> google
##opencv -- computer vision --> we need to install
## keras DL

## ----------------text  analytics-------------
#NLTK (natural language tool kit)
# scipy

#BERT Transformers(ML+DL+NLP) --> Hugging Face (This is a library)
# transformers

##ChatGPT model --> generative AI (ML+DL+NLP)
## LLM 


##streamlit/flask

# %% [markdown]
# $step-1$
# ** Import Packages **

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # $Step-2$
#
# **Read the data**

# %%
# file location
# file name
# extension

#<file_location> //< file_name>.<extension>

#visa datasets

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
pd.read_csv(file_name)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## while reading the file we need to take care of many things
## file path , headers , sep

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## quick checks
type(visa_dataset)

## string list dic set tupl int float bool complex 
##pandas dataframe type 

## place your dataset where python code is there
# Out:
# pandas.core.frame.DataFrame

# %%
visa_dataset.shape
## m*n --> m --> no of rows
## n--> no of columns
## matrix
# Out:
# (25480, 12)

# %%
type(visa_dataset.shape)
# Out:
# tuple

# %%
## number of rows are 25480
print("The number of rows are : ",visa_dataset.shape[0])
## number of columns are 12
print("The number of columns are : ",visa_dataset.shape[1])
# Out:
# The number of rows are :  25480
# The number of columns are :  12

# %%
len(visa_dataset) ## number of rows
# Out:
# 25480

# %%
visa_dataset.size ## number of rows * number of columns --> total values
# Out:
# 305760

# %%
visa_dataset.columns ## names of the columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
#visa_dataset ## rows is not present
dir(visa_dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
visa_dataset.head() ## top 5 rows
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_dataset.head ## function shld have ()
# Out:
# <bound method NDFrame.head of          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset.tail()  ## last 5 rows
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_dataset.tail(10)  ## returns last 10 rows
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %%
visa_dataset.take([0,1,2])
# default axis =0
# axis =0  rows
# axis = 1 columns
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_dataset.take([0,1,2],axis=1)
# Out:
#          case_id continent education_of_employee
# 0         EZYV01      Asia           High School
# 1         EZYV02      Asia              Master's
# 2         EZYV03      Asia            Bachelor's
# 3         EZYV04      Asia            Bachelor's
# 4         EZYV05    Africa              Master's
# ...          ...       ...                   ...
# 25475  EZYV25476      Asia            Bachelor's
# 25476  EZYV25477      Asia           High School
# 25477  EZYV25478      Asia              Master's
# 25478  EZYV25479      Asia              Master's
# 25479  EZYV25480      Asia            Bachelor's
#
# [25480 rows x 3 columns]

# %%
visa_dataset.take([100,200,300]) ## default axis=0 ; rows
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_dataset.take([100,200,300] , axis = 1)

# %%
# I want 150 250 350 rows from 5,8,12 columns
visa_dataset.take([5,8],axis=1).take([150,250,350])
# Out:
#      no_of_employees  prevailing_wage
# 150            50351         529.1105
# 250             4280       61147.0700
# 350             1894      106937.8400

# %%
visa_dataset.take([150,250,350]).take([0,5,8],axis=1)
# Out:
#      case_id  no_of_employees  prevailing_wage
# 150  EZYV151            50351         529.1105
# 250  EZYV251             4280       61147.0700
# 350  EZYV351             1894      106937.8400

# %%
d1=visa_dataset.take([5,8],axis=1)
d1.take([150,250,350])
# Out:
#      no_of_employees  prevailing_wage
# 150            50351         529.1105
# 250             4280       61147.0700
# 350             1894      106937.8400

# %% [markdown]
# # 22-08-2023

# %% [markdown]
# $loc$-$iloc$

# %%
<dataframe>.iloc[rows,columns]
<dataframe>.iloc[start:end,start:end]

## first 3 columns and 2 to 6th rows
## python index starts with 0

<dataframe>.iloc[1:6,0:3]

##whenever we open jupyter notebook first run the cell import packages
## second read the data

# %%
visa_dataset.iloc[1:6,0:3]
# Out:
#   case_id continent education_of_employee
# 1  EZYV02      Asia              Master's
# 2  EZYV03      Asia            Bachelor's
# 3  EZYV04      Asia            Bachelor's
# 4  EZYV05    Africa              Master's
# 5  EZYV06      Asia              Master's

# %%
## rows from 100 to 105 and columns from 
visa_dataset.iloc[100:106,7:11]
# Out:
#     region_of_employment  prevailing_wage unit_of_wage full_time_position
# 100            Northeast         28243.79         Year                  Y
# 101              Midwest         43421.88         Year                  Y
# 102              Midwest         80253.78         Year                  Y
# 103                 West        115235.95         Year                  Y
# 104            Northeast         95200.86         Year                  N
# 105               Island         41613.52         Year                  Y

# %%
## random fashion
visa_dataset.iloc[[100,200,300]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_dataset.iloc[[100,200,300],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_dataset.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_dataset.iloc[[100,200,300],[7,11]]
# Out:
#     region_of_employment case_status
# 100            Northeast   Certified
# 200                 West   Certified
# 300              Midwest   Certified

# %%
index_row=[100,200,300]
index_col=[7,11]
#<dataframe>.iloc[rows,columns]
visa_dataset.iloc[index_row,index_col]
# Out:
#     region_of_employment case_status
# 100            Northeast   Certified
# 200                 West   Certified
# 300              Midwest   Certified

# %%
##2200 and 1700 fro previaling wage column


## within this we are counting the number / index of the number
## there are 100 columns are there it is not possible to count

# %%
visa_dataset.iloc[[2200,1700],[8]]
# Out:
#       prevailing_wage
# 2200         22856.14
# 1700        177310.49

# %%
## i want 100,200,300 row from
## education_of _employee index :2
## no_of _employees index:5
## case_status:11

visa_dataset.iloc[[100,200,300],[2,5,11]]
# Out:
#     education_of_employee  no_of_employees case_status
# 100              Master's             2227   Certified
# 200             Doctorate             3282   Certified
# 300              Master's             3268   Certified

# %%
## to avoid the count of index we use loc
<dataframe>.loc[rows,columns]

# within column names we can directly write the column names

# %%
visa_dataset.loc[[2200,1700],['prevailing_wage']]
# Out:
#       prevailing_wage
# 2200         22856.14
# 1700        177310.49

# %%
visa_dataset.loc[[100,200,300],['education_of_employee','no_of_employees','case_status']]
# Out:
#     education_of_employee  no_of_employees case_status
# 100              Master's             2227   Certified
# 200             Doctorate             3282   Certified
# 300              Master's             3268   Certified

# %%
## list operations
## we can get the index of any item
list1=['Apple','Bat','Cat','Dog']
list1.index('Bat')
# Out:
# 1

# %%
type(visa_dataset.columns) ## it is not a list

## but we can convert it into lists
# Out:
# pandas.core.indexes.base.Index

# %%
list(visa_dataset.columns)
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols_list=list(visa_dataset.columns) 
cols_list.index('prevailing_wage')
# Out:
# 8

# %%
## if i keep all together
## get 2200,1700 row from prevailing wage using iloc with out manual count
## iloc takes direct column numbers , but whereas loc takes direct column names as input
visa_dataset.columns              ## it is not of list type
cols_list=list(visa_dataset.columns) ## we are converting type cast to list
wage_index=cols_list.index('prevailing_wage') ## getting the index by using index method
visa_dataset.iloc[[2200,1700],[wage_index]] #3 this is apply the iloc
# Out:
#       prevailing_wage
# 2200         22856.14
# 1700        177310.49

# %%
## retrieving the data

# head tail take iloc loc

# %% [markdown]
# # $dtypes$

# %%
visa_dataset.dtypes()
##TypeError: 'Series' object is not callable
#() ==> function or methods
# functions or methods only call
# 1 a
# 2 b
# 3 c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 visa_dataset.dtypes()
#
# TypeError: 'Series' object is not callable

# %%
visa_dataset.dtypes
 ## provides the datatype of each column within the dataset

# %%
visa_dataset.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %% [markdown]
# # object is nothing but categorial column

# %%
# ML Models develop using maths
# we can't directly categorical columns data while tain the models
# we need to convert categorical data to numberical data at some point

##so will specifically works on categorical data
## so it is better to separate categorical and numberical colums

# %%
visa_dataset.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
## i need 2 lists >: categorical list and numerical lists
## i always very much curious on series data == dict or list
## key-value pair('case_id':'object')

# %%
type(visa_dataset.dtypes)

## i may convert into dict
# Out:
# pandas.core.series.Series

# %%
dict_col=dict(visa_dataset.dtypes)
dict_col

# dtype('O')--> object
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %% [markdown]
# # series type can convert into dictionary by using dictionary type casting
#
# # anything either convert into list or dictionary
#
# ## if you give the dictionary or list i can make a dataframe

# %%
##separate categorical and numerical
val=[]
cols_dict=dict(visa_dataset.dtypes)
for key,value in cols_dict.items():
    if(value=='object'):
        val.append(key)
        #print(key,"==========",value)
val
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols_dict=dict(visa_dataset.dtypes)
val=[ key for key,value in cols_dict.items() if value=='object']
val
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
##separate categorical and numerical
#val=[]
cols_dict=dict(visa_dataset.dtypes)
for key,value in cols_dict.items():
    if(value=='O'):
        print(key,"==========",value)
#val
# Out:
# case_id ========== object
# continent ========== object
# education_of_employee ========== object
# has_job_experience ========== object
# requires_job_training ========== object
# region_of_employment ========== object
# unit_of_wage ========== object
# full_time_position ========== object
# case_status ========== object

# %%
##separate categorical and numerical
cat_val,num_val=[],[]
cols_dict=dict(visa_dataset.dtypes)
for key,value in cols_dict.items():
    if(value=='O'):
        cat_val.append(key)
    else:
        num_val.append(key)
cat_val,num_val
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
cols_dict=dict(visa_dataset.dtypes)
cat_list=[key for key,value in cols_dict.items() if value=='O' ]
num_list=[key for key,value in cols_dict.items() if value!='O' ]

cat_list,num_list
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %% [markdown]
# # $info$

# %%
visa_dataset.info()

## how many entries are there : 25480
## start and end index: 0 and 25479
## what is the type of visa_dataset : dataframe
# number of columns : 12
# column name
# Any missing values are there then : Non-Null Count
## Age : 30 roes ==> 10  missing values are thefe : Non-Null Count:20
##(within visadata_set : there are no missing values)
## datatype
## count of different data types
## memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# # $isnull$

# %%
visa_dataset.isnull()

## computer responds as True / False
## if True then value is missed
## False : Val is present
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_dataset.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_dataset.isnull().count()
# Out:
# case_id                  25480
# continent                25480
# education_of_employee    25480
# has_job_experience       25480
# requires_job_training    25480
# no_of_employees          25480
# yr_of_estab              25480
# region_of_employment     25480
# prevailing_wage          25480
# unit_of_wage             25480
# full_time_position       25480
# case_status              25480
# dtype: int64
