# %% [markdown]
# # convert categorical to numerical data
# - Before we develop ML algorithm , it is very important to do
# - ML algorithms developed with maths (only numbers)
#
# ## 4 Methods are:
# - Map
# - np.where
# - pd.getDummies
# - LabelEncoder

# %% [markdown]
# # Import the packages

# %%
import numpy as np
import pandas as pd

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
##Separate Numerical and categorical columns
visa_dataset.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
cat,num=[],[]
for key,values in dict(visa_dataset.dtypes).items():
    if values=='O':
        cat.append(key)
    else:
        num.append(key)
        
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
categorical=[key for key,values in dict(visa_dataset.dtypes).items() if values=="object"]
numeric=[key for key,values in dict(visa_dataset.dtypes).items() if values!="object"]
print(categorical,numeric)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status'] ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# # Method-1----> Mapping

# %%
# Case_status is a categorical column
keys=visa_dataset['case_status'].unique()
print(keys,len(keys))
values=[i for i in range(len(keys))]
values

# How many labels are there
# In case_status two labels are there
#      Denied =0
#      Certified=1
# Out:
# ['Denied' 'Certified'] 2
# [0, 1]

# %%
visa_dataset['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %%
visa_dataset['case_status'].unique() ## to get the labels
# denied =0
# certified =1
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
# create a dictionary with denied =0 and certified=1
dict1={'Denied':0,'Certified':1}
dict1
# Out:
# {'Denied': 0, 'Certified': 1}

# %%
# which col labels you want map with dict
visa_dataset['case_status'].map(dict1)
## here it has been in methods , so it does not modify the values
## store this in another variablle new col
# Out:
# 0        0
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 25475    1
# 25476    1
# 25477    1
# 25478    1
# 25479    1
# Name: case_status, Length: 25480, dtype: int64

# %%
## How to create a new col
visa_dataset.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
## wanted to create a new column with number
## Check the shape of the original dataset
visa_dataset.shape ##25480 - values with 12 cols
# Out:
# (25480, 12)

# %%
list1=[i for i in range(25480)]
#list1
len(list1)
# Out:
# 25480

# %% [markdown]
# # creating a addditional col

# %%
visa_dataset['Number']=list1

# %%
visa_dataset.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status', 'Number'],
#       dtype='object')

# %%
visa_dataset.shape
# Out:
# (25480, 13)

# %%
visa_dataset['Number2']=2
## creating another column with value as 2
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Drop the columns

# %%
# number col is created , I want to drop that
# col means axis=1
visa_dataset.drop('Number',axis=1,inplace=True)
## inplace=True --> whatever the operation we r doing will be replaced in visa_dataset only

# %%
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset.drop('Number2',axis=1,inplace=True)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## all together creating the columns
list1=[i for i in range(25480)]
visa_dataset['Number']=list1
visa_dataset['Number2']=2
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## all together dropping the columns
visa_dataset.drop('Number',axis=1,inplace=True)
visa_dataset.drop('Number2',axis=1,inplace=True)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## read the data again
## steps:1 check the labels
visa_dataset['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
## step:2 Create a dictionary
dict1={'Denied':0,'Certified':1}

# %%
## step:3 Map to the feature
visa_dataset['case_status']=visa_dataset['case_status'].map(dict1)
#visa_dataset['case_status1']=visa_dataset['case_status'].map(dict1) ## new case_status

# %%
visa_dataset
## case_status== cat labels (( we will drop this one))
## case_status1=num labels === ML
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## steps:1 check the labels
visa_dataset['case_status'].unique()
## step:2 Create a dictionary
dict1={'Denied':0,'Certified':1}
## step:3 Map to the feature
visa_dataset['case_status']=visa_dataset['case_status'].map(dict1)
## in this we are overriding the case_status values to 0's and 1's
visa_dataset['case_status1']=visa_dataset['case_status'].map(dict1)
visa_dataset.drop('case_status1',axis=1,inplace=True)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## Now for full_time_position
visa_dataset['full_time_position'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
dict2={"Y":11,"N":00}
visa_dataset['full_time_position']=visa_dataset['full_time_position'].map(dict2)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Drawback of map method

# %%
- creating a dictionary: manually we are doing
-  It is very problematic when we have 20  or 100lables

# %%
## Two lists --> dicitionary
list1=['Ram','Sita','Laxman']
list2=[25,22,20]

dict1={list1[i]:list2[i] for i in range(len(list1))}
dict1
## o/p--dict1={'Ram':25,'Sita':22,'Laxman':20}
# Out:
# {'Ram': 25, 'Sita': 22, 'Laxman': 20}

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
keys=visa_dataset['case_status'].unique()
#len(keys)==2
values=[i for i in range(len(keys))]
print(keys)
print(values)

# Dictonary comprehenshion
# If i give two list how to make dictionary

#{<key>:<value>  for loop}
# Out:
# ['Denied' 'Certified']
# [0, 1]

# %%
## Dictionary comprehension
## If i give you two lists , how to make dictionary
dict1={}
for i in keys:
    dict1[i]=values
## Home work
{<key>:<value> for loop}
## to automate  now we do mapping

# %% [markdown]
# # Method:2 -- > np.where

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
##np.where(<condition>,0,1) ==> if cond is true then 0 or else 1
##np.where(visa_dataset['case_status']=='Denied',0,1)
##np.where is only for 2 values like denied and certified
cond1=visa_dataset['case_status']=='Denied'
visa_dataset['case_status']=np.where(cond1,0,1)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # Drawback of np.where
# - It is applicable for only binary labels(ie . two labels)

# %% [markdown]
# # Method:3 -- > pd.get_dummies

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset['education_of_employee'].unique()
## in map 0,1,23
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
## in pd.getdummies
pd.get_dummies(visa_dataset['education_of_employee'])

# there 4 lables are there
# pd.get_dummies will create extra 4 columns
#  B   D    H   M
#   0   0    1   0  ==> actual value within original
#   0   0    0   1

# ON-OFF            SET-RESET
# ON-OFF   ====== > COS function
# COS 0=1            COS 90=0
#  0-degrees        90 

# both are perpendicular each other
# orthogonal each other
# 90 degrees phase shift
# there is no relation, between the B,D,H,M ==> independent each other
# Out:
#        Bachelor's  Doctorate  High School  Master's
# 0               0          0            1         0
# 1               0          0            0         1
# 2               1          0            0         0
# 3               1          0            0         0
# 4               0          0            0         1
# ...           ...        ...          ...       ...
# 25475           1          0            0         0
# 25476           0          0            1         0
# 25477           0          0            0         1
# 25478           0          0            0         1
# 25479           1          0            0         0
#
# [25480 rows x 4 columns]

# %% [markdown]
# # 01/09/2023

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset['case_status'].unique()
# denied =0
# certified =1
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
pd.get_dummies(visa_dataset['case_status'])
# Out:
#        Certified  Denied
# 0              0       1
# 1              1       0
# 2              0       1
# 3              0       1
# 4              1       0
# ...          ...     ...
# 25475          1       0
# 25476          1       0
# 25477          1       0
# 25478          1       0
# 25479          1       0
#
# [25480 rows x 2 columns]

# %%
pd.get_dummies(visa_dataset,columns=['case_status'])## prefix as case_status 
# creates new two cols with labels as suffix
# case_status_certified              --->
# case_status_denied                 --> dummies cols
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
df1=pd.get_dummies(visa_dataset,columns=['case_status'])
df1.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status_Certified', 'case_status_Denied'],
#       dtype='object')

# %%
len(df1.columns)
# Out:
# 13

# %%
visa_dataset.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(visa_dataset.columns)
# Out:
# 12

# %%
pd.get_dummies(visa_dataset,prefix='naresh_it',columns=['case_status'])
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat,num=[],[]
for key,values in dict(visa_dataset.dtypes).items():
    if values=='O':
        cat.append(key)
    else:
        num.append(key)
        
cat,num
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
len(cat)
# Out:
# 9

# %%
cat[1:] ## case_id col is been dropping since it was with only one label
# Out:
# ['continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa_dataset['continent'].nunique()
# Out:
# 6

# %%
s=0
for i in cat[1:]:
    a=visa_dataset[i].nunique()
    s+=a
print(s)
#27 extra columns will be created
# Out:
# 27

# %%
visa_dataset.shape
# Out:
# (25480, 12)

# %%
#12-9=3
#3 are numerical 
# 9 are categorical ==27
# 30 cols

12----->30
256x256 ===== size(huge size then)
We are increasing dimensions
data will be sparse

curse of dimensionality -- pixels(increasing number of cols+)
- Memory issue
- time complexity
- learning process will be show

# %%
## advantages and disadvantages of pd.get_dummies:

# %%
Less data go with pd.get_dummmies
advantage:
    - No relation'
    - Perpendicular
    - 90 phase
    - orthogonality
    - columns are independent each other
disadvantage:
curse of dimensionality -- pixels(increasing number of cols+)
- Memory issue
- time complexity
- learning process will be show

# %% [markdown]
# # Method-4:  LabelEncoder

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
## Automation of map method
keys=visa_dataset['continent'].unique()
values=[i for i in range(len(keys))]
{keys[i]:values[i] for i in range(len(keys))}
#visa_dataset['continent'].map(d)
## Asia:0 , Africa:1 --->
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
## Automation of map method
keys=visa_dataset['continent'].unique()
values=[i for i in range(len(keys))]
d={keys[i]:values[i] for i in range(len(keys))}
visa_dataset['continent'].map(d)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: continent, Length: 25480, dtype: int64

# %%
# read the data again

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
from  sklearn.preprocessing import LabelEncoder ##ML is the heart of the ML
le=LabelEncoder()
le.fit_transform(visa_dataset['continent'])

## steps:
## step-1 > import the package
## step-2> save the package
## step-3> apply fit trasform
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from  sklearn.preprocessing import LabelEncoder
le=LabelEncoder() 
output=le.fit_transform(visa_dataset['continent'])
output[:10]  ## africa as 0 and asia as 1 and soo on
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 3, 1, 2])

# %%
from  sklearn.preprocessing import LabelEncoder   ## import the package -- same steps for all the sklearn process
le=LabelEncoder() # save the package
visa_dataset['continent_new']=le.fit_transform(visa_dataset['continent']) ## Apply fit transform
visa_dataset
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_dataset[['continent','continent_new']]
# Out:
#       continent  continent_new
# 0          Asia              1
# 1          Asia              1
# 2          Asia              1
# 3          Asia              1
# 4        Africa              0
# ...         ...            ...
# 25475      Asia              1
# 25476      Asia              1
# 25477      Asia              1
# 25478      Asia              1
# 25479      Asia              1
#
# [25480 rows x 2 columns]

# %%
visa_dataset['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
visa_dataset['continent_new'].unique()
# Out:
# array([1, 0, 3, 2, 5, 4])

# %%
from  sklearn.preprocessing import LabelEncoder   ## import the package -- same steps for all the sklearn process
le=LabelEncoder() # save the package
fit=le.fit_transform() # apply the fit transform
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 from  sklearn.preprocessing import LabelEncoder   ## import the package -- same steps for all the sklearn process
#       2 le=LabelEncoder() # save the package
# ----> 3 fit=le.fit_transform()
#
# TypeError: LabelEncoder.fit_transform() missing 1 required positional argument: 'X'

# %%
file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset

from  sklearn.preprocessing import LabelEncoder   ## import the package -- same steps for all the sklearn process
le=LabelEncoder() # save the package
visa_dataset['continent']=le.fit_transform(visa_dataset['continent']) ## Apply fit transform
visa_dataset
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          1           High School                  N
# 1         EZYV02          1              Master's                  Y
# 2         EZYV03          1            Bachelor's                  N
# 3         EZYV04          1            Bachelor's                  N
# 4         EZYV05          0              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          1            Bachelor's                  Y
# 25476  EZYV25477          1           High School                  Y
# 25477  EZYV25478          1              Master's                  Y
# 25478  EZYV25479          1              Master's                  Y
# 25479  EZYV25480          1            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # le.inverse_transform

# %%
#visa_dataset['continent']=le.fit_transform(visa_dataset['continent']) --> converted
converted=visa_dataset['continent'].values 
original=le.inverse_transform(visa_dataset['continent'])

# %%
print(converted[:10])
print(original[:10])
# Out:
# [1 1 1 1 0 1 1 3 1 2]
# ['Asia' 'Asia' 'Asia' 'Asia' 'Africa' 'Asia' 'Asia' 'North America' 'Asia'
#  'Europe']

# %%
## All together

file_name="C:\\Users\\S Nikitha\\Downloads\\Visadataset - Visadataset.csv"
visa_dataset=pd.read_csv(file_name)
visa_dataset

from  sklearn.preprocessing import LabelEncoder   ## import the package -- same steps for all the sklearn process
le=LabelEncoder() # save the package

for i in cat[1:]:
    visa_dataset[i]=le.fit_transform(visa_dataset[i]) ## Apply fit transform

visa_dataset
   
#s=0
#for i in cat[1:]:
#    a=visa_dataset[i].nunique()
#    s+=a
#print(s)
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          1                      2                   0
# 1         EZYV02          1                      3                   1
# 2         EZYV03          1                      0                   0
# 3         EZYV04          1                      0                   0
# 4         EZYV05          0                      3                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          1                      0                   1
# 25476  EZYV25477          1                      2                   1
# 25477  EZYV25478          1                      3                   1
# 25478  EZYV25479          1                      3                   1
# 25479  EZYV25480          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# $Fit$-$transform$

# %%
## fit means you are setting up to create an output
##case_status
## certified denied
## 0              1
# d={'c':0,'d':1} ================ fit
keys=visa_dataset['continent'].unique()
values=[i for i in range(len(keys))]
d={keys[i]:values[i] for i in range(len(keys))}
## 3 steps are fit
#transform that output an original data
visa_dataset['continent'].map(d)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 25475    0
# 25476    0
# 25477    0
# 25478    0
# 25479    0
# Name: continent, Length: 25480, dtype: int64

# %%
age: 20 21 22 NAN 25
## step-1: calculate the mean
## step-2: apply on data the mean(transform)
